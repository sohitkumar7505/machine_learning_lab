# %% [markdown]
# <a href="https://colab.research.google.com/github/sohitkumar7505/machine_learning_lab/blob/main/regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv(r"/content/sample_data/advertising.csv")

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
import matplotlib.pyplot as plt
plt.scatter(data['TV'], data['Sales'])
plt.xlabel('TV')

plt.ylabel('Sales')
plt.title('TV Advertising Budget vs Sales')
# Out:
# Text(0.5, 1.0, 'TV Advertising Budget vs Sales')

# %%
x=data['TV']
y=data['Sales']

# %%
def calculateavg(x):
    return sum(x)/len(x)

# %%
numsum=0
densum=0
avgvalx=calculateavg(x)
avgvaly=calculateavg(y)
for i in range(len(x)):
    temp1=x[i]-avgvalx
    temp2=y[i]-avgvaly
    numsum=numsum+temp1*temp2
    densum=densum+temp1*temp1

# %%
numsum,densum
# Out:
# (np.float64(81356.78074999999), np.float64(1466819.0287500012))

# %%
m=numsum/densum
m
# Out:
# np.float64(0.055464770469558805)

# %%
b=avgvaly-m*avgvalx
b
# Out:
# np.float64(6.9748214882299)

# %%
plt.scatter(x, y)
plt.plot(x, m*x+b, color='red')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.title('TV Advertising Budget vs Sales')
plt.show()

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
