# %% [markdown]
# <a href="https://colab.research.google.com/github/sohitkumar7505/machine_learning_lab/blob/main/decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import math

data = {
    'Outlook': ['Sunny','Sunny','Overcast','Rain','Rain','Rain','Overcast','Sunny','Sunny','Rain','Sunny','Overcast','Overcast','Rain'],
    'Temperature': ['Hot','Hot','Hot','Mild','Cool','Cool','Cool','Mild','Cool','Mild','Mild','Mild','Hot','Mild'],
    'Humidity': ['High','High','High','High','Normal','Normal','Normal','High','Normal','Normal','Normal','High','Normal','High'],
    'Wind': ['Weak','Strong','Weak','Weak','Weak','Strong','Strong','Weak','Weak','Weak','Strong','Strong','Weak','Strong'],
    'PlayTennis': ['No','No','Yes','Yes','Yes','No','Yes','No','Yes','Yes','Yes','Yes','Yes','No']
}

df = pd.DataFrame(data)

dic = {}

def entrophy(df):
    target = df['PlayTennis']
    total = len(target)
    value_counts = target.value_counts()
    entropy = 0
    for val in value_counts:
        p = val / total
        entropy -= p * math.log2(p)
    return entropy

def information_gain(df):
    global dic
    dic = {}
    base_entropy = entrophy(df)
    for i in df.columns:
        if i == 'PlayTennis':
            continue
        total = base_entropy
        weighted_entropy = 0
        for j in df[i].unique():
            df1 = df[df[i] == j]
            weighted_entropy += (len(df1) / len(df)) * entrophy(df1)
        total -= weighted_entropy
        dic[i] = total
    return dic

def decision_tree(df):
    dic = information_gain(df)
    if len(df.columns) == 1:
        return
    selected_column = max(dic, key=dic.get)
    print(selected_column)
    for j in df[selected_column].unique():
        tempdf = df[df[selected_column] == j].drop(columns=[selected_column])
        print(selected_column, "=", j)
        decision_tree(tempdf)

decision_tree(df)
# Out:
# Outlook
# Outlook = Sunny
# Humidity
# Humidity = High
# Temperature
# Temperature = Hot
# Wind
# Wind = Weak
# Wind = Strong
# Temperature = Mild
# Wind
# Wind = Weak
# Humidity = Normal
# Temperature
# Temperature = Cool
# Wind
# Wind = Weak
# Temperature = Mild
# Wind
# Wind = Strong
# Outlook = Overcast
# Temperature
# Temperature = Hot
# Humidity
# Humidity = High
# Wind
# Wind = Weak
# Humidity = Normal
# Wind
# Wind = Weak
# Temperature = Cool
# Humidity
# Humidity = Normal
# Wind
# Wind = Strong
# Temperature = Mild
# Humidity
# Humidity = High
# Wind
# Wind = Strong
# Outlook = Rain
# Wind
# Wind = Weak
# Temperature
# Temperature = Mild
# Humidity
# Humidity = High
# Humidity = Normal
# Temperature = Cool
# Humidity
# Humidity = Normal
# Wind = Strong
# Temperature
# Temperature = Cool
# Humidity
# Humidity = Normal
# Temperature = Mild
# Humidity
# Humidity = High
